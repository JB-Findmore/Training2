# %% [markdown]
# # Formação 2 - Machine Learning Development in Python
# ---
# *João Brazuna*

# %% [markdown]
# ## Apresentação dos Conjuntos de Dados
# ---
# Nesta formação, usaremos maioritariamente dois conjuntos de dados reais e de acesso livre:

# %% [markdown]
# ### [**Titanic**](https://www.kaggle.com/competitions/titanic/data)
# <img src="images/Titanic.jpg" width="200">
#
# Os dados do Titanic contêm informação real sobre os passageiros e a indicação se o passageiro sobreviveu ou não, que é aquilo que se pretende que seja previsto.
#
# |  ID  | Variável    | Descrição                                 | Valores                                                              |
# | ---: | :----       | :----                                     | :---                                                                 |
# |    0 | PassengerId | ID do Passageiro                          | 1, 2, 3,..., 891                                                     |
# |    1 | Survival    | Indicatriz da Sobrevivência do Passageiro | 1 se o passageiro tiver sobrevivido, 0 caso contrário                |
# |    2 | Pclass      | Classe Económica do Passageiro            | 1 para 1ª classe, 2 para 2ª classe e 3 para passageiros de 3ª classe |
# |    3 | Name        | Nome do Passageiro                        | Nome do passageiro, incluindo o título (Mr., Miss., Mrs.,...)        |
# |    4 | Sex         | Género do Passageiro                      | "male" ou "female"                                                   |
# |    5 | Age         | Idade do Passageiro em Anos               | 0.42, 0.67, 0.75, 0.83, 0.92, 1, 2,...                               |
# |    6 | SibSp       | Número de Irmãos e Cônjuges no Titanic    | 0, 1, 2,...                                                          |
# |    7 | Parch       | Número de Pais e Filhos no Titanic        | 0, 1, 2,...                                                          |
# |    8 | Ticket      | Número do Bilhete                         | "A/5 21171", "PC 17599", "STON/O2. 3101282",...                      |
# |    9 | Fare        | Preço do Bilhete                          | 0, 4.0125, 5, 6.2375,...                                             |
# |   10 | Cabin       | Camarote onde ficou o Passageiro          | "C85", "C123", "E46",...                                             |
# |   11 | Embarked    | Porto onde o Passageiro Embarcou          | "C" para Cherbourg, "Q" para Queenstown ou "S" para Southampton      |

# %% [markdown]
# ### [**Desempenho dos Alunos**](https://archive.ics.uci.edu/ml/datasets/student%2Bperformance)
# <img src="images/PTMAT.jpg" width="200">
#
# Contém dados sobre alunos de duas escolas portuguesas, incluindo as suas notas das disciplinas de Português e Matemática nos 3 períodos. O objectivo é prever a nota final de cada aluno numa das disciplinas.
#
#
# | ID  | Variável    | Descrição                                 | Valores            |
# | ---: | :---- | :---- | :--- |
# |  1 | school     | Escola do Aluno                          | "GP" - Gabriel Pereira ou "MS" - Mousinho da Silveira|
# |  2 | sex        | Género do Aluno                          | "F" - feminino ou "M" - masculino |
# |  3 | age        | Idade do Aluno                           | De 15 a 22 |
# |  4 | address    | Tipo de Localidade de Residência         | "U" - urbana ou "R" - rural |
# |  5 | famsize    | Tamanho da Família                       | "LE3" - menor ou igual a 3 ou "GT3" - maior que 3 |
# |  6 | Pstatus    | Estado de Coabitação dos Pais            | "T" - juntos ou "A" - separados |
# |  7 | Medu       | Educação da Mãe                          | 0 - Nenhuma,  1 - Educação Primária (4º Ano), 2 – 5º ao 9º Ano, 3 – Educação Secundária ou 4 – Educação Superior |
# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
import seaborn as sns

import optuna
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, plot_tree
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor, GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.cluster import KMeans

import statsmodels.api as sm

import lightgbm as lgb
import xgboost as xgb

import h2o
from h2o.estimators import H2OGradientBoostingEstimator, H2OXGBoostEstimator

# %% [markdown]
# ## Exemplo de Regressão Linear Simples
# ---

# %%
X = pd.DataFrame({'1': [1] * 12,
                  'X': [32, 48, 72, 64, 48, 16, 40, 48, 48, 24, 80, 56]})
X
# Out:
#     1   X
# 0   1  32
# 1   1  48
# 2   1  72
# 3   1  64
# 4   1  48
# 5   1  16
# 6   1  40
# 7   1  48
# 8   1  48
# 9   1  24
# 10  1  80
# 11  1  56

# %%
y = pd.Series([230, 262, 323, 298, 255, 199, 248, 279, 267, 214, 359, 305])
y
# Out:
# 0     230
# 1     262
# 2     323
# 3     298
# 4     255
# 5     199
# 6     248
# 7     279
# 8     267
# 9     214
# 10    359
# 11    305
# dtype: int64

# %% [markdown]
# $$\hat{\mathbf{\beta}} = \left(\mathbf{X}^{T} \mathbf{X}\right)^{-1} \mathbf{X}^{T} \mathbf{y}$$

# %%
betas = np.matmul(np.linalg.inv(np.matmul((X.T).values, X.values)), np.matmul((X.T).values, y.values))
betas
# Out:
# array([153.91666667,   2.41666667])

# %% [markdown]
# ## Carregar os Dados
# ---

# %%
titanic_df = pd.read_csv('data/Titanic.csv')
titanic_df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
students_df = pd.read_csv('data/students.csv')
students_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher  \
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 365     MS   F   19       R     GT3       T     2     3  services     other
# 366     MS   F   18       U     LE3       T     3     1   teacher  services
# 367     MS   F   18       U     GT3       T     1     1     other     other
# 368     MS   M   17       U     LE3       T     3     1  services  services
# 369     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... paid_por activities_por Dalc_por Walc_por  health_por absences_por
# 0    ...       no             no        1        1           3            4  \
# 1    ...       no             no        1        1           3            2
# 2    ...       no             no        2        3           3            6
# 3    ...       no            yes        1        1           5            0
# 4    ...       no             no        1        2           5            0
# ..   ...      ...            ...      ...      ...         ...          ...
# 365  ...       no            yes        1        2           5            4
# 366  ...       no             no        1        1           1            4
# 367  ...       no            yes        1        1           5            6
# 368  ...       no             no        3        4           2            6
# 369  ...       no             no        3        4           5            4
#
#     G1_por  G2_por  G3_por  studytime
# 0        0      11      11          4
# 1        9      11      11          4
# 2       12      13      12          4
# 3       14      14      14          6
# 4       11      13      13          4
# ..     ...     ...     ...        ...
# 365     10      11      10          6
# 366     15      15      16          4
# 367     11      12       9          4
# 368     10      10      10          2
# 369     10      11      11          2
#
# [370 rows x 47 columns]

# %% [markdown]
# ## Regressão Linear - Prever Nota Final a Matemática
# ---

# %%
numeric_vars = students_df.dtypes[students_df.dtypes != 'object'].index.to_list()
numeric_vars
# Out:
# ['age',
#  'Medu',
#  'Fedu',
#  'traveltime',
#  'famrel',
#  'freetime',
#  'goout',
#  'studytime_mat',
#  'failures_mat',
#  'Dalc_mat',
#  'Walc_mat',
#  'health_mat',
#  'absences_mat',
#  'G1_mat',
#  'G2_mat',
#  'G3_mat',
#  'studytime_por',
#  'failures_por',
#  'Dalc_por',
#  'Walc_por',
#  'health_por',
#  'absences_por',
#  'G1_por',
#  'G2_por',
#  'G3_por',
#  'studytime']

# %%
X = students_df[['school'] + numeric_vars].drop('G3_mat', axis=1)
y = students_df['G3_mat']
X
# Out:
#     school  age  Medu  Fedu  traveltime  famrel  freetime  goout
# 0       GP   18     4     4           2       4         3      4  \
# 1       GP   17     1     1           1       5         3      3
# 2       GP   15     1     1           1       4         3      2
# 3       GP   15     4     2           1       3         2      2
# 4       GP   16     3     3           1       4         3      2
# ..     ...  ...   ...   ...         ...     ...       ...    ...
# 365     MS   19     2     3           1       5         4      2
# 366     MS   18     3     1           1       4         3      4
# 367     MS   18     1     1           2       1         1      1
# 368     MS   17     3     1           2       2         4      5
# 369     MS   18     3     2           3       4         4      1
#
#      studytime_mat  failures_mat  ...  studytime_por  failures_por  Dalc_por
# 0                2             0  ...              2             0         1  \
# 1                2             0  ...              2             0         1
# 2                2             3  ...              2             0         2
# 3                3             0  ...              3             0         1
# 4                2             0  ...              2             0         1
# ..             ...           ...  ...            ...           ...       ...
# 365              3             1  ...              3             1         1
# 366              2             0  ...              2             0         1
# 367              2             1  ...              2             0         1
# 368              1             0  ...              1             0         3
# 369              1             0  ...              1             0         3
#
#      Walc_por  health_por  absences_por  G1_por  G2_por  G3_por  studytime
# 0           1           3             4       0      11      11          4
# 1           1           3             2       9      11      11          4
# 2           3           3             6      12      13      12          4
# 3           1           5             0      14      14      14          6
# 4           2           5             0      11      13      13          4
# ..        ...         ...           ...     ...     ...     ...        ...
# 365         2           5             4      10      11      10          6
# 366         1           1             4      15      15      16          4
# 367         1           5             6      11      12       9          4
# 368         4           2             6      10      10      10          2
# 369         4           5             4      10      11      11          2
#
# [370 rows x 26 columns]

# %%
X['school'].value_counts()
# Out:
# school
# GP    331
# MS     39
# Name: count, dtype: int64

# %%
X['school'] = pd.get_dummies(X['school'], drop_first=True)['MS'].astype(int)
X
# Out:
#      school  age  Medu  Fedu  traveltime  famrel  freetime  goout
# 0         0   18     4     4           2       4         3      4  \
# 1         0   17     1     1           1       5         3      3
# 2         0   15     1     1           1       4         3      2
# 3         0   15     4     2           1       3         2      2
# 4         0   16     3     3           1       4         3      2
# ..      ...  ...   ...   ...         ...     ...       ...    ...
# 365       1   19     2     3           1       5         4      2
# 366       1   18     3     1           1       4         3      4
# 367       1   18     1     1           2       1         1      1
# 368       1   17     3     1           2       2         4      5
# 369       1   18     3     2           3       4         4      1
#
#      studytime_mat  failures_mat  ...  studytime_por  failures_por  Dalc_por
# 0                2             0  ...              2             0         1  \
# 1                2             0  ...              2             0         1
# 2                2             3  ...              2             0         2
# 3                3             0  ...              3             0         1
# 4                2             0  ...              2             0         1
# ..             ...           ...  ...            ...           ...       ...
# 365              3             1  ...              3             1         1
# 366              2             0  ...              2             0         1
# 367              2             1  ...              2             0         1
# 368              1             0  ...              1             0         3
# 369              1             0  ...              1             0         3
#
#      Walc_por  health_por  absences_por  G1_por  G2_por  G3_por  studytime
# 0           1           3             4       0      11      11          4
# 1           1           3             2       9      11      11          4
# 2           3           3             6      12      13      12          4
# 3           1           5             0      14      14      14          6
# 4           2           5             0      11      13      13          4
# ..        ...         ...           ...     ...     ...     ...        ...
# 365         2           5             4      10      11      10          6
# 366         1           1             4      15      15      16          4
# 367         1           5             6      11      12       9          4
# 368         4           2             6      10      10      10          2
# 369         4           5             4      10      11      11          2
#
# [370 rows x 26 columns]

# %%
y
# Out:
# 0       6
# 1       6
# 2      10
# 3      15
# 4      10
#        ..
# 365     0
# 366     8
# 367     0
# 368    16
# 369    10
# Name: G3_mat, Length: 370, dtype: int64

# %%
lm = sm.OLS(y, sm.add_constant(X))
res = lm.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 G3_mat   R-squared:                       0.846
# Model:                            OLS   Adj. R-squared:                  0.836
# Method:                 Least Squares   F-statistic:                     90.78
# Date:                Thu, 20 Apr 2023   Prob (F-statistic):          2.96e-127
# Time:                        20:45:48   Log-Likelihood:                -744.19
# No. Observations:                 370   AIC:                             1532.
# Df Residuals:                     348   BIC:                             1618.
# Df Model:                          21
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.1946      1.787      0.109      0.913      -3.321       3.710
# school            0.3357      0.368      0.912      0.363      -0.389       1.060
# age              -0.2880      0.099     -2.912      0.004      -0.483      -0.093
# Medu              0.0456      0.121      0.377      0.707      -0.193       0.284
# Fedu             -0.0976      0.119     -0.820      0.413      -0.332       0.137
# traveltime        0.0736      0.151      0.487      0.626      -0.223       0.370
# famrel            0.3462      0.112      3.103      0.002       0.127       0.566
# freetime          0.0241      0.108      0.223      0.823      -0.188       0.236
# goout             0.0859      0.103      0.837      0.403      -0.116       0.288
# studytime_mat    -0.0315      0.021     -1.511      0.132      -0.073       0.009
# failures_mat     -0.2528      0.175     -1.448      0.149      -0.596       0.091
# Dalc_mat         -0.0251      0.075     -0.335      0.738      -0.173       0.122
# Walc_mat          0.0695      0.055      1.259      0.209      -0.039       0.178
# health_mat        0.0392      0.036      1.090      0.277      -0.032       0.110
# absences_mat      0.0647      0.016      4.144      0.000       0.034       0.095
# G1_mat            0.1276      0.061      2.085      0.038       0.007       0.248
# G2_mat            0.9418      0.053     17.724      0.000       0.837       1.046
# studytime_por    -0.0315      0.021     -1.511      0.132      -0.073       0.009
# failures_por      0.3043      0.249      1.220      0.223      -0.186       0.795
# Dalc_por         -0.0251      0.075     -0.335      0.738      -0.173       0.122
# Walc_por          0.0695      0.055      1.259      0.209      -0.039       0.178
# health_por        0.0392      0.036      1.090      0.277      -0.032       0.110
# absences_por     -0.0588      0.025     -2.366      0.019      -0.108      -0.010
# G1_por           -0.0415      0.087     -0.476      0.634      -0.213       0.130
# G2_por            0.1397      0.116      1.208      0.228      -0.088       0.367
# G3_por            0.0279      0.077      0.361      0.718      -0.124       0.179
# studytime        -0.0630      0.042     -1.511      0.132      -0.145       0.019
# ==============================================================================
# Omnibus:                      184.265   Durbin-Watson:                   1.832
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              929.848
# Skew:                          -2.144   Prob(JB):                    1.22e-202
# Kurtosis:                       9.475   Cond. No.                     1.01e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.15e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
initial_X = X.copy()

# %%
vars_to_delete = ['G3_por', 'freetime', 'Dalc_mat', 'Dalc_por', 'G1_por', 'Medu', 'traveltime', 'Fedu', 'goout', 'health_por', 'health_mat', 'failures_por', 'failures_mat', 'studytime', 'studytime_por']
vars_to_keep = [x for x in numeric_vars if x not in vars_to_delete + ['G3_mat']]
X = initial_X[['school'] + vars_to_keep]

# %%
lm2 = sm.OLS(y, sm.add_constant(X))
res2 = lm2.fit()
res2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 G3_mat   R-squared:                       0.843
# Model:                            OLS   Adj. R-squared:                  0.839
# Method:                 Least Squares   F-statistic:                     193.0
# Date:                Thu, 20 Apr 2023   Prob (F-statistic):          8.65e-138
# Time:                        20:45:48   Log-Likelihood:                -747.11
# No. Observations:                 370   AIC:                             1516.
# Df Residuals:                     359   BIC:                             1559.
# Df Model:                          10
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0248      1.589      0.016      0.988      -3.101       3.150
# school            0.3096      0.345      0.896      0.371      -0.370       0.989
# age              -0.2568      0.092     -2.795      0.005      -0.438      -0.076
# famrel            0.3895      0.108      3.620      0.000       0.178       0.601
# studytime_mat    -0.1857      0.122     -1.528      0.127      -0.425       0.053
# Walc_mat          0.0786      0.041      1.929      0.054      -0.002       0.159
# absences_mat      0.0631      0.015      4.180      0.000       0.033       0.093
# G1_mat            0.1413      0.058      2.435      0.015       0.027       0.255
# G2_mat            0.9430      0.051     18.430      0.000       0.842       1.044
# Walc_por          0.0786      0.041      1.929      0.054      -0.002       0.159
# absences_por     -0.0601      0.024     -2.487      0.013      -0.108      -0.013
# G2_por            0.1102      0.052      2.098      0.037       0.007       0.213
# ==============================================================================
# Omnibus:                      192.267   Durbin-Watson:                   1.834
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1023.381
# Skew:                          -2.235   Prob(JB):                    5.96e-223
# Kurtosis:                       9.812   Cond. No.                     5.77e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.32e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
y.mean()
# Out:
# 10.464864864864865

# %%
y.sample(frac=0.2, replace=False, random_state=123).mean()
# Out:
# 10.743243243243244

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (296, 11) (74, 11) (296,) (74,)

# %%
y_train.mean()
# Out:
# 10.39527027027027

# %%
y_test.mean()
# Out:
# 10.743243243243244

# %%
lm3 = sm.OLS(y_train, sm.add_constant(X_train))
res3 = lm3.fit()
res3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 G3_mat   R-squared:                       0.842
# Model:                            OLS   Adj. R-squared:                  0.836
# Method:                 Least Squares   F-statistic:                     151.7
# Date:                Thu, 20 Apr 2023   Prob (F-statistic):          6.73e-108
# Time:                        20:45:48   Log-Likelihood:                -596.84
# No. Observations:                 296   AIC:                             1216.
# Df Residuals:                     285   BIC:                             1256.
# Df Model:                          10
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.6188      1.827      0.339      0.735      -2.978       4.216
# school            0.5480      0.382      1.433      0.153      -0.205       1.301
# age              -0.2734      0.107     -2.544      0.011      -0.485      -0.062
# famrel            0.4545      0.118      3.853      0.000       0.222       0.687
# studytime_mat    -0.2738      0.131     -2.086      0.038      -0.532      -0.015
# Walc_mat          0.0671      0.046      1.457      0.146      -0.024       0.158
# absences_mat      0.0651      0.016      3.950      0.000       0.033       0.098
# G1_mat            0.1253      0.065      1.942      0.053      -0.002       0.252
# G2_mat            0.9458      0.055     17.222      0.000       0.838       1.054
# Walc_por          0.0671      0.046      1.457      0.146      -0.024       0.158
# absences_por     -0.0731      0.027     -2.733      0.007      -0.126      -0.020
# G2_por            0.0990      0.060      1.661      0.098      -0.018       0.216
# ==============================================================================
# Omnibus:                      164.938   Durbin-Watson:                   2.020
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              948.683
# Skew:                          -2.320   Prob(JB):                    9.91e-207
# Kurtosis:                      10.443   Cond. No.                     8.71e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.9e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
res3.params
# Out:
# const            0.618773
# school           0.548004
# age             -0.273356
# famrel           0.454528
# studytime_mat   -0.273818
# Walc_mat         0.067149
# absences_mat     0.065083
# G1_mat           0.125314
# G2_mat           0.945772
# Walc_por         0.067149
# absences_por    -0.073133
# G2_por           0.098954
# dtype: float64

# %%
new_X_test = X_test.assign(const=1)
new_X_test = new_X_test[['const'] + X_test.columns.difference(['const']).to_list()]
new_X_test
# Out:
#      const  G1_mat  G2_mat  G2_por  Walc_mat  Walc_por  absences_mat
# 59       1      15      16      15         1         1             2  \
# 245      1       6       8       8         4         4             0
# 9        1      14      15      12         1         1             0
# 300      1       8       8      12         2         2             0
# 291      1      10       8      14         2         2            10
# ..     ...     ...     ...     ...       ...       ...           ...
# 301      1       9      10      15         1         1             9
# 196      1       8      10      12         3         3             6
# 218      1      12      13       9         5         5             0
# 6        1      12      12      12         1         1             0
# 162      1      14      15      17         1         1             0
#
#      absences_por  age  famrel  school  studytime_mat
# 59              2   16       4       0              2
# 245             8   18       4       0              1
# 9               0   15       5       0              2
# 300             2   18       5       0              2
# 291             0   18       4       0              2
# ..            ...  ...     ...     ...            ...
# 301             2   18       4       0              3
# 196             4   16       4       0              2
# 218             9   18       3       0              2
# 6               0   16       4       0              2
# 162             0   16       4       0              2
#
# [74 rows x 12 columns]

# %%
np.round(np.matmul(new_X_test.values, res3.params.values), 0)
# Out:
# array([27., 23., 24., 26., 28., 25., 25., 25., 22., 28., 27., 27., 30.,
#        23., 28., 28., 27., 27., 26., 29., 29., 27., 26., 27., 25., 27.,
#        24., 26., 22., 24., 28., 30., 28., 27., 24., 29., 29., 27., 23.,
#        23., 24., 22., 22., 29., 26., 28., 28., 31., 24., 27., 23., 26.,
#        22., 26., 27., 25., 27., 25., 23., 27., 21., 20., 24., 33., 23.,
#        22., 23., 23., 24., 28., 24., 25., 25., 27.])

# %%
lm4 = LinearRegression()
lm4.fit(X_train, y_train)
lm4.score(X_train, y_train)
# Out:
# 0.8418691760425664

# %%
lm4.score(X_test, y_test)
# Out:
# 0.8419791248949797

# %%
y_pred = lm4.predict(X_test)
y_pred
# Out:
# array([16.13012066,  6.30447528, 15.50615642,  7.30182878,  8.09293707,
#         8.00391787,  8.89330083,  3.076151  ,  3.95082862, 13.80671301,
#        18.0824697 ,  9.13709649, 13.74784874, 12.15409825,  6.54867977,
#        18.60684108, 12.26260612, 15.27789279, 11.02130951, 18.66504871,
#        10.38659511,  6.55001162,  7.71474782, 11.02838391, 15.14887646,
#         8.95971725, 13.20090662, 16.6314989 , 10.02540945,  4.19257124,
#        -2.03527793, 11.46409173, 10.65257966, 11.75792145,  8.48686756,
#        11.66105896,  9.15019909, 14.22831444,  5.62110751, 11.35190772,
#        14.07949571,  9.35122668,  6.13059964, 15.81025883, 15.29473828,
#        18.94254444, 14.5569205 , 17.70504367, 12.93157461, 16.52393862,
#         4.08847702, 17.65670611, 14.18056835, 10.70517175, 11.26950277,
#         8.08513817,  8.23205912, 11.91690315,  9.89435091,  9.24757004,
#         9.33716722,  7.35258867, 12.8399478 , 10.33020817,  5.92182767,
#        11.82494583,  9.31056754, 13.45428749,  6.56240796,  9.3386551 ,
#         9.66409104, 11.21699541, 11.69032718, 15.27304021])

# %%
final_test = X_test.assign(**{'Actual': y_test, 'Estimate': y_pred})
final_test
# Out:
#      school  age  famrel  studytime_mat  Walc_mat  absences_mat  G1_mat
# 59        0   16       4              2         1             2      15  \
# 245       0   18       4              1         4             0       6
# 9         0   15       5              2         1             0      14
# 300       0   18       5              2         2             0       8
# 291       0   18       4              2         2            10      10
# ..      ...  ...     ...            ...       ...           ...     ...
# 301       0   18       4              3         1             9       9
# 196       0   16       4              2         3             6       8
# 218       0   18       3              2         5             0      12
# 6         0   16       4              2         1             0      12
# 162       0   16       4              2         1             0      14
#
#      G2_mat  Walc_por  absences_por  G2_por  Actual   Estimate
# 59       16         1             2      15      16  16.130121
# 245       8         4             8       8       8   6.304475
# 9        15         1             0      12      15  15.506156
# 300       8         2             2      12       0   7.301829
# 291       8         2             0      14       8   8.092937
# ..      ...       ...           ...     ...     ...        ...
# 301      10         1             2      15       9   9.338655
# 196      10         3             4      12      10   9.664091
# 218      13         5             9       9      13  11.216995
# 6        12         1             0      12      11  11.690327
# 162      15         1             0      17      16  15.273040
#
# [74 rows x 13 columns]

# %%
class ConfusionMatrix():
    def __init__(self, y_real, y_pred):
        if (len(np.intersect1d(y_real, [1, 0])) != 2) or len(y_real.unique()) != 2:
            raise ValueError(f"y_real parameter can only take levels 1 or 0.")
        cm = confusion_matrix(y_real, y_pred, labels=[1, 0])
        cm_df = pd.DataFrame(cm, index=['Real Positive', 'Real Negative'], columns=['Predicted Positive', 'Predicted Negative'])
        self._confusion_matrix = cm_df
    
    @property
    def confusion_matrix(self):
        return self._confusion_matrix
    
    @property
    def tp(self):
        return self.confusion_matrix.loc['Real Positive', 'Predicted Positive']
    
    @property
    def tn(self):
        return self.confusion_matrix.loc['Real Negative', 'Predicted Negative']
    
    @property
    def fp(self):
        return self.confusion_matrix.loc['Real Negative', 'Predicted Positive']
    
    @property
    def fn(self):
        return self.confusion_matrix.loc['Real Positive', 'Predicted Negative']
    
    @property
    def positive(self):
        return self.confusion_matrix.loc['Real Positive', :].sum()
    
    @property
    def negative(self):
        return self.confusion_matrix.loc['Real Negative', :].sum()
    
    @property
    def predicted_positive(self):
        return self.confusion_matrix.loc[:, 'Predicted Positive'].sum()
    
    @property
    def predicted_negative(self):
        return self.confusion_matrix.loc[:, 'Predicted Negative'].sum()
    
    ## Performance Measures ##
    @property
    def accuracy(self):
        return (self.tp + self.tn) / (self.positive + self.negative)
    
    # Sensibility
    @property
    def sensibility(self):
        return self.tp / self.positive
    
    @property
    def recall(self):
        return self.sensibility
    
    @property
    def tpr(self):
        return self.sensibility
    
    # Specificity
    @property
    def specificity(self):
        return self.tn / self.negative
    
    @property
    def selectivity(self):
        return self.specificity
    
    @property
    def tpr(self):
        return self.specificity
    
    # False Positive Rate
    @property
    def fpr(self):
        return 1 - self.specificity
    
    # False Negative Rate
    @property
    def fnr(self):
        return 1 - self.sensitivity
    
    # PPV / Precision
    @property
    def precision(self):
        return self.tp / self.predicted_positive
    
    @property
    def ppv(self):
        return self.precision
    
    # NPV
    @property
    def npv(self):
        return self.tn / self.predicted_negative
    
    # False Discovery Rate
    @property
    def fdr(self):
        return 1 - self.ppv
    
    # False Omission Rate
    @property
    def fomr(self):
        return 1 - self.npv
    
    # Performance Measures
    @property
    def performance_measures(self):
        pm_dct = {'Accuracy': self.accuracy,
                  'Precision / PPV': self.precision,
                  'Recall / Sensibility': self.sensibility,
                  'NPV': self.npv,
                  'Specificity': self.specificity}
        return pd.Series(pm_dct).to_frame('Performance Measures').T
    
    
def target_by_feature(x, target, data, fun='mean', bins=None,
                      xlabel=None, ylabel=None, title=None, targetlabels=None, 
                      xrotation=None, show=True):
    df = data.copy()
    df['Number of Observations'] = 1
    
    if isinstance(target, str):
        targets = [target]
    elif isinstance(target, list) and all([isinstance(y, str) for y in target]):
        targets = target
    else:
        raise ValueError(f"target argument can only be a string or a list of strings")
    
    if targetlabels is None:
        targetlabels = targets
    elif (isinstance(targetlabels, str) and len(targets) == 1):
        targetlabels = [targetlabels]
    elif ((isinstance(targetlabels, str) and len(targets) != 1)) or (isinstance(targetlabels, list) and (len(targetlabels) != len(targets))):
        raise ValueErrors(f"targetlabels argument must be a string if target is a string or a singleton list, or a list with the same number of elements as target.")

    if bins is not None:
        if isinstance(bins, list):
            if len(bins) != 3:
                raise ValueError(f"When a list, bins must be have 3 elements")
            bins = [df[x].min() - bins[2], *np.arange(bins[0], bins[1], bins[2]).tolist(), df[x].max()]     
            n_bins = len(bins)
        elif isinstance(bins, int):
            n_bins = bins
            
        unique_vals = df[x].unique()
        if len(unique_vals) > n_bins:
            df[x] = pd.cut(df[x], bins=bins)#.apply(lambda x: x.right)
    
    agg_funs = {'Number of Observations': 'sum'}
    for target in targets:
        agg_funs[target] = fun
    
    grp_df = df.groupby(x).agg(agg_funs).sort_index()
    grp_df['Number of Observations (%)'] = grp_df['Number of Observations'] / grp_df['Number of Observations'].sum() * 100
    grp_df.reset_index(inplace=True)
    
    ax = sns.barplot(x=x, y='Number of Observations (%)', data=grp_df, color='grey', alpha=0.4)
    ax.yaxis.set_major_formatter(PercentFormatter(decimals=0))
    ylims = ax.get_ylim()
    y_adj = (ylims[1] - ylims[0]) / 100
    
    for ii, p in enumerate(ax.patches):
        txt = str(int(grp_df.iloc[ii]['Number of Observations']))
        txt_x = p.get_x() + p.get_width() / 2
        txt_y = p.get_height() + y_adj
        ax.text(txt_x, txt_y, txt, ha='center')
    
    ax2 = ax.twinx()
    
    for target in targets:
        sns.lineplot(x=ax.get_xticks(), y=target, data=grp_df, ax=ax2)
    
    if xlabel is None:
        xlabel = x.title()
    ax.set_xlabel(xlabel)
    
    preffix = 'Average ' if fun in ['mean', np.mean] else 'Sum ' if fun in ['sum', np.sum] else ''
    if ylabel is None:
        ylabel = preffix + 'Target Value' 
    ax2.set_ylabel(ylabel)
    
    if title is None:
        title = ylabel + ' by ' + xlabel
    ax.set_title(title)
    
    plt.legend(labels=targetlabels, bbox_to_anchor=(1.7,1))
    
    if xrotation is not None:
        ax.tick_params(axis='x', rotation=90)
    if show:
        plt.show()

# %%
target_by_feature(x='age', target=['Actual', 'Estimate'], 
                  data=final_test, fun='mean', bins=None,
                  xlabel='Idade', ylabel='Nota Final Média a Matemática', 
                  title='Nota Final Média a Matemática por Idade', targetlabels=None, 
                  xrotation=None, show=True)

# %% [markdown]
# ## Clustering via K-Means

# %%
km = KMeans(n_clusters=3, random_state=123)
train_preds = km.fit_predict(X_train[['G1_mat', 'G2_mat']])
train_preds
# Out:
# C:\Users\joaop\.conda\envs\env\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\joaop\.conda\envs\env\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# array([2, 2, 0, 0, 2, 0, 2, 1, 2, 1, 1, 1, 2, 2, 1, 2, 0, 2, 1, 1, 2, 2,
#        0, 1, 2, 2, 1, 2, 2, 0, 1, 0, 1, 2, 0, 1, 0, 2, 2, 1, 2, 1, 0, 2,
#        2, 2, 2, 1, 1, 2, 2, 0, 2, 0, 0, 2, 0, 0, 1, 2, 0, 1, 0, 0, 1, 2,
#        2, 0, 0, 2, 0, 1, 2, 0, 0, 2, 2, 1, 2, 1, 1, 2, 2, 1, 2, 2, 0, 2,
#        2, 1, 2, 0, 0, 2, 2, 1, 0, 1, 1, 1, 1, 2, 1, 0, 0, 0, 2, 2, 1, 2,
#        0, 2, 0, 1, 2, 2, 0, 2, 0, 2, 0, 2, 1, 0, 0, 2, 0, 1, 0, 0, 0, 0,
#        0, 2, 2, 1, 0, 0, 1, 2, 0, 2, 1, 0, 0, 0, 2, 2, 1, 0, 2, 0, 2, 1,
#        2, 1, 1, 0, 1, 0, 2, 1, 2, 0, 2, 2, 2, 0, 1, 2, 1, 1, 0, 2, 1, 2,
#        1, 2, 0, 2, 1, 1, 2, 2, 1, 2, 0, 0, 2, 0, 2, 2, 1, 0, 2, 2, 1, 2,
#        2, 1, 1, 2, 1, 0, 1, 0, 0, 0, 2, 0, 2, 1, 0, 0, 2, 2, 2, 1, 2, 0,
#        1, 1, 1, 1, 0, 0, 2, 2, 1, 1, 0, 2, 1, 1, 1, 1, 1, 0, 0, 2, 0, 2,
#        0, 0, 2, 2, 2, 2, 1, 1, 1, 2, 1, 2, 1, 2, 2, 1, 1, 2, 1, 1, 2, 1,
#        2, 0, 0, 2, 1, 2, 2, 1, 1, 0, 0, 1, 2, 1, 2, 0, 2, 0, 1, 0, 0, 0,
#        2, 0, 2, 1, 0, 2, 2, 2, 2, 1])

# %%
clusters = pd.concat([pd.Series(train_preds, name='Clusters'),
                      y_train.reset_index(drop=True)], axis=1)
clusters
# Out:
#      Clusters  G3_mat
# 0           2      10
# 1           2      14
# 2           0      15
# 3           0      15
# 4           2       0
# ..        ...     ...
# 291         2      10
# 292         2      10
# 293         2      14
# 294         2      10
# 295         1       0
#
# [296 rows x 2 columns]

# %%
clusters.groupby('Clusters')['G3_mat'].mean().sort_values(ascending=False)
# Out:
# Clusters
# 0    15.090909
# 2    10.420168
# 1     5.719101
# Name: G3_mat, dtype: float64

# %%
[plt.scatter(x='index', y='G3_mat', color=color, data=clusters[clusters['Clusters']==i].reset_index()) for i, color in enumerate(['blue', 'green', 'red'])]
plt.show()

# %%
test_preds = km.predict(X_test[['G1_mat', 'G2_mat']])

# %%
clusters_test = pd.concat([pd.Series(test_preds, name='Clusters'),
                           y_test.reset_index(drop=True)], axis=1)
clusters_test
# Out:
#     Clusters  G3_mat
# 0          0      16
# 1          1       8
# 2          0      15
# 3          1       0
# 4          2       8
# ..       ...     ...
# 69         2       9
# 70         2      10
# 71         2      13
# 72         2      11
# 73         0      16
#
# [74 rows x 2 columns]

# %%
clusters_test.groupby('Clusters')['G3_mat'].mean().sort_values(ascending=False)
# Out:
# Clusters
# 0    15.28
# 2    10.60
# 1     5.00
# Name: G3_mat, dtype: float64

# %%
[plt.scatter(x='index', y='G3_mat', color=color, data=clusters_test[clusters_test['Clusters']==i].reset_index()) for i, color in enumerate(['blue', 'green', 'red'])]
plt.show()

# %% [markdown]
# ## Regressão Logística - Prever a Probabilidade de Sobrevivência

# %%
numeric_vars = titanic_df.dtypes[titanic_df.dtypes != 'object'].index.to_list()

# %%
X = titanic_df[numeric_vars].drop(['PassengerId', 'Survived'], axis=1).dropna(axis=1)
y = titanic_df['Survived']
X
# Out:
#      Pclass  SibSp  Parch     Fare
# 0         3      1      0   7.2500
# 1         1      1      0  71.2833
# 2         3      0      0   7.9250
# 3         1      1      0  53.1000
# 4         3      0      0   8.0500
# ..      ...    ...    ...      ...
# 886       2      0      0  13.0000
# 887       1      0      0  30.0000
# 888       3      1      2  23.4500
# 889       1      0      0  30.0000
# 890       3      0      0   7.7500
#
# [891 rows x 4 columns]

# %%
lm = sm.Logit(y, sm.add_constant(X))
res = lm.fit()
res.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.599982
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Survived   No. Observations:                  891
# Model:                          Logit   Df Residuals:                      886
# Method:                           MLE   Df Model:                            4
# Date:                Thu, 20 Apr 2023   Pseudo R-squ.:                 0.09901
# Time:                        20:45:53   Log-Likelihood:                -534.58
# converged:                       True   LL-Null:                       -593.33
# Covariance Type:            nonrobust   LLR p-value:                 1.838e-24
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9117      0.300      3.035      0.002       0.323       1.501
# Pclass        -0.6953      0.112     -6.188      0.000      -0.916      -0.475
# SibSp         -0.1465      0.081     -1.812      0.070      -0.305       0.012
# Parch          0.2557      0.099      2.580      0.010       0.061       0.450
# Fare           0.0051      0.002      2.097      0.036       0.000       0.010
# ==============================================================================
# """

# %%
lm2 = LogisticRegression(random_state=123)
lm2.fit(X, y)
lm2.score(X, y)
# Out:
# 0.6879910213243546

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (712, 4) (179, 4) (712,) (179,)

# %%
lm2.fit(X_train, y_train)
lm2.score(X_train, y_train)
# Out:
# 0.6867977528089888

# %%
lm2.score(X_test, y_test)
# Out:
# 0.6983240223463687

# %%
confusion_matrix(y_test, lm2.predict(X_test), labels=[1, 0])
# Out:
# array([[35, 30],
#        [24, 90]], dtype=int64)

# %%
(35 + 90) / (35 + 90 + 24 + 30)
# Out:
# 0.6983240223463687

# %%
y_pred = lm2.predict(X_test)

# %%
cm = ConfusionMatrix(y_test, lm2.predict(X_test))
cm.confusion_matrix.T
# Out:
#                     Real Positive  Real Negative
# Predicted Positive             35             24
# Predicted Negative             30             90

# %%
cm.performance_measures
# Out:
#                       Accuracy  Precision / PPV  Recall / Sensibility   NPV
# Performance Measures  0.698324          0.59322              0.538462  0.75  \
#
#                       Specificity
# Performance Measures     0.789474

# %% [markdown]
# ## Métodos de Árvores
# ---

# %% [markdown]
# ### Árvores de Decisão

# %%
tree_clf = DecisionTreeClassifier(
    # Hiperparâmetros (sklearn default)
    criterion='gini',
    splitter='best',
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    min_weight_fraction_leaf=0,
    max_features=None,
    max_leaf_nodes=None,
    min_impurity_decrease=0,
    class_weight=None,
    ccp_alpha=0,
    # Reproducibilidade
    random_state=123)

tree_clf.fit(X_train, y_train)
tree_clf.score(X_test, y_test)
# Out:
# 0.7374301675977654

# %%
cm = ConfusionMatrix(y_test, tree_clf.predict(X_test))
cm.confusion_matrix.T
# Out:
#                     Real Positive  Real Negative
# Predicted Positive             40             22
# Predicted Negative             25             92

# %%
cm.performance_measures
# Out:
#                       Accuracy  Precision / PPV  Recall / Sensibility
# Performance Measures   0.73743         0.645161              0.615385  \
#
#                            NPV  Specificity
# Performance Measures  0.786325     0.807018

# %%
plot_tree(tree_clf, feature_names=X_train.columns, max_depth=2)
plt.show()

# %%
param_grid = {'criterion': ['gini', 'entropy', 'log_loss'],
              'random_state': [123]}

tree_gs = GridSearchCV(
    estimator=DecisionTreeClassifier(),
    param_grid=param_grid,
    scoring='accuracy',
    n_jobs=None,
    refit=True,
    cv=5,  # default = None
)
tree_gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'random_state': [123]},
#              scoring='accuracy')

# %%
tree_gs.best_score_
# Out:
# 0.6432581503004038

# %%
tree_gs.best_params_
# Out:
# {'criterion': 'entropy', 'random_state': 123}

# %%
tree_gs.best_estimator_.score(X_test, y_test)
# Out:
# 0.7486033519553073

# %%
tuned_tree_clf = DecisionTreeClassifier(
    **tree_gs.best_params_)

tuned_tree_clf.fit(X_train, y_train)
tuned_tree_clf.score(X_test, y_test)
# Out:
# 0.7486033519553073

# %%
param_grid = {'criterion': ['gini', 'entropy', 'log_loss'],
              'random_state': [123]}

tree_rs = RandomizedSearchCV(
    estimator=DecisionTreeClassifier(),
    param_distributions=param_grid,
    n_iter=2,
    scoring='accuracy',
    n_jobs=None,
    refit=True,
    cv=5,  # default = None
    random_state=123
)
tree_rs.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_iter=2,
#                    param_distributions={'criterion': ['gini', 'entropy',
#                                                       'log_loss'],
#                                         'random_state': [123]},
#                    random_state=123, scoring='accuracy')

# %%
tree_rs.best_score_
# Out:
# 0.6432581503004038

# %%
tree_rs.best_params_
# Out:
# {'random_state': 123, 'criterion': 'entropy'}

# %%
tuned_tree_clf = tree_rs.best_estimator_
tuned_tree_clf.score(X_test, y_test)
# Out:
# 0.7486033519553073

# %%
def tree_objective(trial):
    
    max_depth = None  # trial.suggest_int('max_depth', 2, 64)
    criterion = trial.suggest_categorical('criterion', ['gini', 'entropy', 'log_loss'])
    
    clf = DecisionTreeClassifier(criterion=criterion, max_depth=max_depth, random_state=123)
    cv_score = cross_val_score(clf, X_train, y_train, cv=5, scoring='accuracy')
    
    return cv_score.mean()
    
tree_study = optuna.create_study(direction='maximize')
tree_study.optimize(tree_objective, n_trials=2)
# Out:
# [I 2023-04-20 20:45:55,976] A new study created in memory with name: no-name-6f13dfd7-aa48-4974-9620-a66c2782dbec
# [I 2023-04-20 20:45:56,120] Trial 0 finished with value: 0.6432581503004038 and parameters: {'criterion': 'log_loss'}. Best is trial 0 with value: 0.6432581503004038.
# [I 2023-04-20 20:45:56,260] Trial 1 finished with value: 0.6432581503004038 and parameters: {'criterion': 'log_loss'}. Best is trial 0 with value: 0.6432581503004038.

# %%
tree_study.best_value
# Out:
# 0.6432581503004038

# %%
tree_study.best_params
# Out:
# {'criterion': 'log_loss'}

# %%
tuned_tree_clf = DecisionTreeClassifier(
    random_state=123,
    **tree_study.best_params)

tuned_tree_clf.fit(X_train, y_train)
tuned_tree_clf.score(X_test, y_test)
# Out:
# 0.7486033519553073

# %%
cm = ConfusionMatrix(y_test, tuned_tree_clf.predict(X_test))
cm.confusion_matrix.T
# Out:
#                     Real Positive  Real Negative
# Predicted Positive             41             21
# Predicted Negative             24             93

# %%
cm.performance_measures
# Out:
#                       Accuracy  Precision / PPV  Recall / Sensibility
# Performance Measures  0.748603          0.66129              0.630769  \
#
#                            NPV  Specificity
# Performance Measures  0.794872     0.815789

# %% [markdown]
# ### Florestas Aleatórias: Médias / Eleição por Maioria de Razão de Árvores (*Bagging*)

# %%
rf_clf = RandomForestClassifier(
    # Hiperparâmetros - Florestas (sklearn default)
    n_estimators=100,
    bootstrap=True,
    oob_score=False,
    max_samples=None,
    warm_start=False,
    # Hiperparâmetros - Árvores (sklearn default)
    criterion='gini',
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    min_weight_fraction_leaf=0,
    max_features=None,
    max_leaf_nodes=None,
    min_impurity_decrease=0,
    class_weight=None,
    ccp_alpha=0,
    # Reproducibilidade
    random_state=123,
    verbose=0,
    # Computação em Paralelo
    n_jobs=None)

rf_clf.fit(X_train, y_train)
rf_clf.score(X_test, y_test)
# Out:
# 0.7430167597765364

# %%
imp_df = pd.DataFrame({'Variable': X_train.columns.to_list(), 'Importance': rf_clf.feature_importances_.tolist()}).sort_values(by='Importance', ascending=False)
imp_df
# Out:
#   Variable  Importance
# 3     Fare    0.693311
# 0   Pclass    0.113273
# 1    SibSp    0.106369
# 2    Parch    0.087046

# %%
def rf_objective(trial):
    
    max_depth = trial.suggest_int('max_depth', 2, 64)
    
    clf = RandomForestClassifier(max_depth=max_depth, random_state=123)
    cv_score = cross_val_score(clf, X_train, y_train, cv=5, scoring='accuracy')
    
    return cv_score.mean()
    
rf_study = optuna.create_study(direction='maximize')
rf_study.optimize(rf_objective, n_trials=5)
# Out:
# [I 2023-04-20 20:45:56,985] A new study created in memory with name: no-name-7e9802f0-1135-4476-89b7-2064e1223ae5
# [I 2023-04-20 20:45:58,531] Trial 0 finished with value: 0.6432581503004038 and parameters: {'max_depth': 64}. Best is trial 0 with value: 0.6432581503004038.
# [I 2023-04-20 20:46:00,071] Trial 1 finished with value: 0.6432581503004038 and parameters: {'max_depth': 37}. Best is trial 0 with value: 0.6432581503004038.
# [I 2023-04-20 20:46:01,626] Trial 2 finished with value: 0.68687087560327 and parameters: {'max_depth': 8}. Best is trial 2 with value: 0.68687087560327.
# [I 2023-04-20 20:46:04,175] Trial 3 finished with value: 0.6742539150989856 and parameters: {'max_depth': 9}. Best is trial 2 with value: 0.68687087560327.
# [I 2023-04-20 20:46:06,108] Trial 4 finished with value: 0.6432581503004038 and parameters: {'max_depth': 43}. Best is trial 2 with value: 0.68687087560327.

# %%
rf_study.best_value
# Out:
# 0.68687087560327

# %%
rf_study.best_params
# Out:
# {'max_depth': 8}

# %%
tuned_rf_clf = RandomForestClassifier(
    random_state=123,
    **rf_study.best_params)

tuned_rf_clf.fit(X_train, y_train)
tuned_rf_clf.score(X_test, y_test)
# Out:
# 0.7653631284916201

# %%
cm = ConfusionMatrix(y_test, tuned_rf_clf.predict(X_test))
cm.confusion_matrix.T
# Out:
#                     Real Positive  Real Negative
# Predicted Positive             42             19
# Predicted Negative             23             95

# %%
cm.performance_measures
# Out:
#                       Accuracy  Precision / PPV  Recall / Sensibility
# Performance Measures  0.765363         0.688525              0.646154  \
#
#                            NPV  Specificity
# Performance Measures  0.805085     0.833333

# %% [markdown]
# ### Gradient Boosting Machines: Árvore a corrigir Árvores (*Boosting*)

# %%
gbm_clf = GradientBoostingClassifier(
    # Hiperparâmetros - GBM (sklearn default)
    loss='log_loss',
    learning_rate=0.1,
    subsample=1,
    n_estimators=100,
    criterion='friedman_mse',
    warm_start=False,
    init=None,
    validation_fraction=0.1, 
    n_iter_no_change=None, 
    tol=0.0001,
    # Hiperparâmetros - Árvores (sklearn default)
    # criterion='gini',
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    min_weight_fraction_leaf=0,
    max_features=None,
    max_leaf_nodes=None,
    min_impurity_decrease=0,
    # class_weight=None,
    ccp_alpha=0,
    # Reproducibilidade
    random_state=123,
    verbose=0)

gbm_clf.fit(X_train, y_train)
gbm_clf.score(X_test, y_test)
# Out:
# 0.7430167597765364

# %%
imp_df = pd.DataFrame({'Variable': X_train.columns.to_list(), 'Importance': gbm_clf.feature_importances_.tolist()}).sort_values(by='Importance', ascending=False)
imp_df
# Out:
#   Variable  Importance
# 3     Fare    0.693451
# 0   Pclass    0.169402
# 1    SibSp    0.076976
# 2    Parch    0.060170

# %%
def gbm_objective(trial):
    
    max_depth = trial.suggest_int('max_depth', 2, 64)
    
    clf = GradientBoostingClassifier(max_depth=max_depth, random_state=123)
    cv_score = cross_val_score(clf, X_train, y_train, cv=5, scoring='accuracy')
    
    return cv_score.mean()
    
gbm_study = optuna.create_study(direction='maximize')
gbm_study.optimize(gbm_objective, n_trials=5)
# Out:
# [I 2023-04-20 20:46:08,285] A new study created in memory with name: no-name-74ecebfa-9fff-4cd5-a1ac-8f881c710d26
# [I 2023-04-20 20:46:13,868] Trial 0 finished with value: 0.63901309957648 and parameters: {'max_depth': 30}. Best is trial 0 with value: 0.63901309957648.
# [I 2023-04-20 20:46:19,888] Trial 1 finished with value: 0.63901309957648 and parameters: {'max_depth': 64}. Best is trial 0 with value: 0.63901309957648.
# [I 2023-04-20 20:46:24,616] Trial 2 finished with value: 0.63901309957648 and parameters: {'max_depth': 25}. Best is trial 0 with value: 0.63901309957648.
# [I 2023-04-20 20:46:28,920] Trial 3 finished with value: 0.63901309957648 and parameters: {'max_depth': 63}. Best is trial 0 with value: 0.63901309957648.
# [I 2023-04-20 20:46:31,580] Trial 4 finished with value: 0.6502807052102827 and parameters: {'max_depth': 9}. Best is trial 4 with value: 0.6502807052102827.

# %%
gbm_study.best_value
# Out:
# 0.6502807052102827

# %%
gbm_study.best_params
# Out:
# {'max_depth': 9}

# %%
tuned_gbm_clf = GradientBoostingClassifier(
    random_state=123,
    **gbm_study.best_params)

tuned_gbm_clf.fit(X_train, y_train)
tuned_gbm_clf.score(X_test, y_test)
# Out:
# 0.7150837988826816

# %%
cm = ConfusionMatrix(y_test, tuned_gbm_clf.predict(X_test))
cm.confusion_matrix.T
# Out:
#                     Real Positive  Real Negative
# Predicted Positive             41             27
# Predicted Negative             24             87

# %%
cm.performance_measures
# Out:
#                       Accuracy  Precision / PPV  Recall / Sensibility
# Performance Measures  0.715084         0.602941              0.630769  \
#
#                            NPV  Specificity
# Performance Measures  0.783784     0.763158

# %%
lgbm_clf = lgb.LGBMClassifier(random_state=123)
lgbm_clf.fit(X_train, y_train)
lgbm_clf.score(X_test, y_test)
# Out:
# 0.7597765363128491

# %%
xgb_clf = xgb.XGBClassifier(random_state=123)
xgb_clf.fit(X_train, y_train)
xgb_clf.score(X_test, y_test)
# Out:
# 0.7486033519553073

# %% [markdown]
# ### H2O e Colocação de um Modelo em Produção

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
# ; Java HotSpot(TM) 64-Bit Server VM 18.9 (build 11.0.19+9-LTS-224, mixed mode)
#   Starting server from C:\Users\joaop\.conda\envs\env\Lib\site-packages\h2o\backend\bin\h2o.jar
#   Ice root: C:\Users\joaop\AppData\Local\Temp\tmprkddyxgh
#   JVM stdout: C:\Users\joaop\AppData\Local\Temp\tmprkddyxgh\h2o_joaop_started_from_python.out
#   JVM stderr: C:\Users\joaop\AppData\Local\Temp\tmprkddyxgh\h2o_joaop_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# Warning: Your H2O cluster version is too old (2 years, 10 months and 19 days)! Please download and install the latest version from http://h2o.ai/download/
# --------------------------  ---------------------------------------------------------
# H2O_cluster_uptime:         07 secs
# H2O_cluster_timezone:       Europe/London
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.30.0.4
# H2O_cluster_version_age:    2 years, 10 months and 19 days !!!
# H2O_cluster_name:           H2O_from_python_joaop_bu7bhz
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    1.980 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.11.2 final
# --------------------------  ---------------------------------------------------------

# %%
train_h2o = h2o.H2OFrame(titanic_df.loc[X_train.index].drop('PassengerId', axis=1))
test_h2o = h2o.H2OFrame(titanic_df.loc[X_test.index].drop('PassengerId', axis=1))
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
train_h2o['Survived'] = train_h2o['Survived'].asfactor()
test_h2o['Survived'] = test_h2o['Survived'].asfactor()

train_h2o['Pclass'] = train_h2o['Pclass'].asfactor()
test_h2o['Pclass'] = test_h2o['Pclass'].asfactor()

# %%
gbm_h2o = H2OGradientBoostingEstimator(
    ntrees=100,  # n_estimators
    learn_rate=0.1,  # learning_rate
    nfolds=5,  # cv
    seed=123  # random_state
)

vars_to_use = titanic_df.columns.difference(['PassengerId', 'Survived', 'Cabin']).to_list()
print(vars_to_use)

gbm_h2o.train(x=vars_to_use,
              y='Survived',
             training_frame=train_h2o)
# Out:
# ['Age', 'Embarked', 'Fare', 'Name', 'Parch', 'Pclass', 'Sex', 'SibSp', 'Ticket']
# gbm Model Build progress: |███████████████████████████████████████████████| 100%

# %%
y_pred = gbm_h2o.predict(test_h2o).as_data_frame()['predict']
y_pred
# Out:
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 174    0
# 175    0
# 176    1
# 177    0
# 178    0
# Name: predict, Length: 179, dtype: int64

# %%
cm = ConfusionMatrix(y_test, y_pred)
cm.confusion_matrix.T
# Out:
#                     Real Positive  Real Negative
# Predicted Positive             53             11
# Predicted Negative             12            103

# %%
cm.performance_measures
# Out:
#                       Accuracy  Precision / PPV  Recall / Sensibility
# Performance Measures  0.871508         0.828125              0.815385  \
#
#                            NPV  Specificity
# Performance Measures  0.895652     0.903509

# %%
gbm_h2o.varimp(True)
# Out:
#    variable  relative_importance  scaled_importance  percentage
# 0       Sex           264.055176           1.000000    0.395893
# 1       Age           112.030830           0.424271    0.167966
# 2    Pclass            89.169281           0.337692    0.133690
# 3      Fare            81.935356           0.310296    0.122844
# 4    Ticket            62.381336           0.236244    0.093527
# 5     SibSp            43.783131           0.165811    0.065643
# 6  Embarked            10.284788           0.038949    0.015420
# 7     Parch             3.346562           0.012674    0.005017

# %%
gbm_h2o.download_mojo('Model.zip')
# Out:
# 'C:\\Users\\joaop\\PycharmProjects\\Training2\\Model.zip'

# %%
gbm_h2o2 = h2o.import_mojo('Model.zip')
gbm_h2o2
# Out:
# generic Model Build progress: |███████████████████████████████████████████| 100%
# Model Details
# =============
# H2OGenericEstimator :  Import MOJO Model
# Model Key:  Generic_model_python_1682020015498_1017
#
#
# Model Summary:
#      number_of_trees  number_of_internal_trees  model_size_in_bytes
# 0              100.0                     100.0              26159.0  \
#
#    min_depth  max_depth  mean_depth  min_leaves  max_leaves  mean_leaves
# 0        5.0        5.0         5.0         6.0        24.0        16.16
# ModelMetricsBinomialGeneric: generic
# ** Reported on train data. **
#
# MSE: 0.048421797694431716
# RMSE: 0.22004953463807125
# LogLoss: 0.18296080296758094
# Mean Per-Class Error: 0.0631934935059546
# AUC: 0.9881447362961119
# AUCPR: 0.9835519450727473
# Gini: 0.9762894725922238
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.4681278038657083:
#               0      1   Error           Rate
# 0      0  423.0   12.0  0.0276   (12.0/435.0)
# 1      1   29.0  248.0  0.1047   (29.0/277.0)
# 2  Total  452.0  260.0  0.0576   (41.0/712.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold       value    idx
# 0                        max f1   0.468128    0.923650  159.0
# 1                        max f2   0.239901    0.941218  212.0
# 2                  max f0point5   0.638104    0.954584  133.0
# 3                  max accuracy   0.468128    0.942416  159.0
# 4                 max precision   0.994938    1.000000    0.0
# 5                    max recall   0.140033    1.000000  259.0
# 6               max specificity   0.994938    1.000000    0.0
# 7              max absolute_mcc   0.468128    0.878635  159.0
# 8    max min_per_class_accuracy   0.340823    0.933333  183.0
# 9   max mean_per_class_accuracy   0.378685    0.936807  174.0
# 10                      max tns   0.994938  435.000000    0.0
# 11                      max fns   0.994938  275.000000    0.0
# 12                      max fps   0.003027  435.000000  399.0
# 13                      max tps   0.140033  277.000000  259.0
# 14                      max tnr   0.994938    1.000000    0.0
# 15                      max fnr   0.994938    0.992780    0.0
# 16                      max fpr   0.003027    1.000000  399.0
# 17                      max tpr   0.140033    1.000000  259.0
# Gains/Lift Table: Avg response rate: 38,90 %, avg score: 38,92 %
#      group  cumulative_data_fraction  lower_threshold      lift
# 0        1                  0.011236         0.993147  2.570397  \
# 1        2                  0.021067         0.991272  2.570397
# 2        3                  0.030899         0.990200  2.570397
# 3        4                  0.040730         0.988547  2.570397
# 4        5                  0.050562         0.986513  2.570397
# 5        6                  0.101124         0.977190  2.570397
# 6        7                  0.150281         0.954641  2.570397
# 7        8                  0.200843         0.916254  2.570397
# 8        9                  0.300562         0.702001  2.570397
# 9       10                  0.400281         0.347583  1.592922
# 10      11                  0.500000         0.180858  0.615447
# 11      12                  0.599719         0.103343  0.072406
# 12      13                  0.700843         0.071083  0.000000
# 13      14                  0.799157         0.048869  0.000000
# 14      15                  0.898876         0.032251  0.000000
# 15      16                  1.000000         0.003027  0.000000
#
#     cumulative_lift  response_rate     score  cumulative_response_rate
# 0          2.570397       1.000000  0.993976                  1.000000  \
# 1          2.570397       1.000000  0.992140                  1.000000
# 2          2.570397       1.000000  0.990810                  1.000000
# 3          2.570397       1.000000  0.989364                  1.000000
# 4          2.570397       1.000000  0.987316                  1.000000
# 5          2.570397       1.000000  0.982159                  1.000000
# 6          2.570397       1.000000  0.966121                  1.000000
# 7          2.570397       1.000000  0.937565                  1.000000
# 8          2.570397       1.000000  0.832270                  1.000000
# 9          2.326886       0.619718  0.527417                  0.905263
# 10         1.985560       0.239437  0.246248                  0.772472
# 11         1.667447       0.028169  0.137874                  0.648712
# 12         1.426854       0.000000  0.083917                  0.555110
# 13         1.251318       0.000000  0.059599                  0.486819
# 14         1.112500       0.000000  0.040417                  0.432812
# 15         1.000000       0.000000  0.022166                  0.389045
#
#     cumulative_score  capture_rate  cumulative_capture_rate        gain
# 0           0.993976      0.028881                 0.028881  157.039711  \
# 1           0.993119      0.025271                 0.054152  157.039711
# 2           0.992385      0.025271                 0.079422  157.039711
# 3           0.991656      0.025271                 0.104693  157.039711
# 4           0.990812      0.025271                 0.129964  157.039711
# 5           0.986485      0.129964                 0.259928  157.039711
# 6           0.979824      0.126354                 0.386282  157.039711
# 7           0.969186      0.129964                 0.516245  157.039711
# 8           0.923760      0.256318                 0.772563  157.039711
# 9           0.825022      0.158845                 0.931408   59.292215
# 10          0.709592      0.061372                 0.992780  -38.455280
# 11          0.614529      0.007220                 1.000000  -92.759445
# 12          0.537968      0.000000                 1.000000 -100.000000
# 13          0.479118      0.000000                 1.000000 -100.000000
# 14          0.430449      0.000000                 1.000000 -100.000000
# 15          0.389162      0.000000                 1.000000 -100.000000
#
#     cumulative_gain
# 0        157.039711
# 1        157.039711
# 2        157.039711
# 3        157.039711
# 4        157.039711
# 5        157.039711
# 6        157.039711
# 7        157.039711
# 8        157.039711
# 9        132.688581
# 10        98.555957
# 11        66.744731
# 12        42.685371
# 13        25.131810
# 14        11.250000
# 15         0.000000
# ModelMetricsBinomialGeneric: generic
# ** Reported on cross-validation data. **
#
# MSE: 0.14044613653796223
# RMSE: 0.3747614395024683
# LogLoss: 0.4708166781605331
# Mean Per-Class Error: 0.19432341590937385
# AUC: 0.8484044981119548
# AUCPR: 0.8292842912769511
# Gini: 0.6968089962239097
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.5201008344861557:
#               0      1   Error            Rate
# 0      0  390.0   45.0  0.1034    (45.0/435.0)
# 1      1   79.0  198.0  0.2852    (79.0/277.0)
# 2  Total  469.0  243.0  0.1742   (124.0/712.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold       value    idx
# 0                        max f1   0.520101    0.761538  149.0
# 1                        max f2   0.101287    0.785623  303.0
# 2                  max f0point5   0.791514    0.824176  100.0
# 3                  max accuracy   0.605478    0.827247  136.0
# 4                 max precision   0.997626    1.000000    0.0
# 5                    max recall   0.009850    1.000000  394.0
# 6               max specificity   0.997626    1.000000    0.0
# 7              max absolute_mcc   0.605478    0.631751  136.0
# 8    max min_per_class_accuracy   0.301059    0.772414  204.0
# 9   max mean_per_class_accuracy   0.520101    0.805677  149.0
# 10                      max tns   0.997626  435.000000    0.0
# 11                      max fns   0.997626  276.000000    0.0
# 12                      max fps   0.002858  435.000000  399.0
# 13                      max tps   0.009850  277.000000  394.0
# 14                      max tnr   0.997626    1.000000    0.0
# 15                      max fnr   0.997626    0.996390    0.0
# 16                      max fpr   0.002858    1.000000  399.0
# 17                      max tpr   0.009850    1.000000  394.0
# Gains/Lift Table: Avg response rate: 38,90 %, avg score: 38,81 %
#      group  cumulative_data_fraction  lower_threshold      lift
# 15    2023-04-20 20:47:14   7.145 sec             15.0       0.321637
# 16    2023-04-20 20:47:14   7.152 sec             16.0       0.318575
# 17    2023-04-20 20:47:14   7.159 sec             17.0       0.314854
# 18    2023-04-20 20:47:14   7.165 sec             18.0       0.312214
# 19    2023-04-20 20:47:14   7.172 sec             19.0       0.309385
#
#     training_logloss  training_auc  training_pr_auc  training_lift
# 0           0.668319      0.500000         0.389045       1.000000  \
# 1           0.615940      0.906892         0.897051       2.570397
# 2           0.573236      0.909772         0.901975       2.570397
# 3           0.539792      0.919594         0.907582       2.570397
# 4           0.509852      0.924553         0.911970       2.570397
# 5           0.484783      0.926661         0.914244       2.570397
# 6           0.462999      0.927748         0.915105       2.570397
# 7           0.444657      0.932404         0.918372       2.570397
# 8           0.428279      0.933412         0.919374       2.570397
# 9           0.414866      0.933246         0.919491       2.570397
# 10          0.402728      0.933715         0.920035       2.570397
# 11          0.392282      0.934977         0.920976       2.570397
# 12          0.381764      0.935454         0.922278       2.570397
# 13          0.372860      0.936006         0.923264       2.570397
# 14          0.364756      0.937753         0.924647       2.570397
# 15          0.357475      0.939172         0.926180       2.570397
# 16          0.350779      0.941213         0.927932       2.570397
# 17          0.343267      0.941566         0.929049       2.570397
# 18          0.337638      0.942836         0.930455       2.570397
# 19          0.332060      0.944330         0.932018       2.570397
#
#     training_classification_error
# 0                        0.610955
# 1                        0.151685
# 2                        0.140449
# 3                        0.140449
# 4                        0.139045
# 5                        0.134831
# 6                        0.133427
# 7                        0.133427
# 8                        0.127809
# 9                        0.126404
# 10                       0.126404
# 11                       0.125000
# 12                       0.122191
# 13                       0.117978
# 14                       0.119382
# 15                       0.117978
# 16                       0.119382
# 17                       0.115169
# 18                       0.115169
# 19                       0.112360
# See the whole table with table.as_data_frame()
#
# Variable Importances:
#    variable  relative_importance  scaled_importance  percentage
# 0       Sex           264.055176           1.000000    0.395893
# 1       Age           112.030830           0.424271    0.167966
# 2    Pclass            89.169281           0.337692    0.133690
# 3      Fare            81.935356           0.310296    0.122844
# 4    Ticket            62.381336           0.236244    0.093527
# 5     SibSp            43.783131           0.165811    0.065643
# 6  Embarked            10.284788           0.038949    0.015420
# 7     Parch             3.346562           0.012674    0.005017
# Model Details
# =============
# H2OGenericEstimator :  Import MOJO Model
# Model Key:  Generic_model_python_1682020015498_1017
#
#
# Model Summary:
#      number_of_trees  number_of_internal_trees  model_size_in_bytes
# 0              100.0                     100.0              26159.0  \
#
#    min_depth  max_depth  mean_depth  min_leaves  max_leaves  mean_leaves
# 0        5.0        5.0         5.0         6.0        24.0        16.16
# ModelMetricsBinomialGeneric: generic
# ** Reported on train data. **
#
# MSE: 0.048421797694431716
# RMSE: 0.22004953463807125
# LogLoss: 0.18296080296758094
# Mean Per-Class Error: 0.0631934935059546
# AUC: 0.9881447362961119
# AUCPR: 0.9835519450727473
# Gini: 0.9762894725922238
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.4681278038657083:
#               0      1   Error           Rate
# 0      0  423.0   12.0  0.0276   (12.0/435.0)
# 1      1   29.0  248.0  0.1047   (29.0/277.0)
# 2  Total  452.0  260.0  0.0576   (41.0/712.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  thresh
# 11          0.614529      0.007220                 1.000000  -92.759445
# 12          0.537968      0.000000                 1.000000 -100.000000
# 13          0.479118      0.000000                 1.000000 -100.000000
# 14          0.430449      0.000000                 1.000000 -100.000000
# 15          0.389162      0.000000                 1.000000 -100.000000
#
#     cumulative_gain
# 0        157.039711
# 1        157.039711
# 2        157.039711
# 3        157.039711
# 4        157.039711
# 5        157.039711
# 6        157.039711
# 7        157.039711
# 8        157.039711
# 9        132.688581
# 10        98.555957
# 11        66.744731
# 12        42.685371
# 13        25.131810
# 14        11.250000
# 15         0.000000
# ModelMetricsBinomialGeneric: generic
# ** Reported on cross-validation data. **
#
# MSE: 0.14044613653796223
# RMSE: 0.3747614395024683
# LogLoss: 0.4708166781605331
# Mean Per-Class Error: 0.19432341590937385
# AUC: 0.8484044981119548
# AUCPR: 0.8292842912769511
# Gini: 0.6968089962239097
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.5201008344861557:
#               0      1   Error            Rate
# 0      0  390.0   45.0  0.1034    (45.0/435.0)
# 1      1   79.0  198.0  0.2852    (79.0/277.0)
# 2  Total  469.0  243.0  0.1742   (124.0/712.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold       value    idx
# 0                        max f1   0.520101    0.761538  149.0
# 1                        max f2   0.101287    0.785623  303.0
# 2                  max f0point5   0.791514    0.824176  100.0
# 3                  max accuracy   0.605478    0.827247  136.0
# 4                 max precision   0.997626    1.000000    0.0
# 5                    max recall   0.009850    1.000000  394.0
# 6               max specificity   0.997626    1.000000    0.0
# 7              max absolute_mcc   0.605478    0.631751  136.0
# 8    max min_per_class_accuracy   0.301059    0.772414  204.0
# 9   max mean_per_class_accuracy   0.520101    0.805677  149.0
# 10                      max tns   0.997626  435.000000    0.0
# 11                      max fns   0.997626  276.000000    0.0
# 12                      max fps   0.002858  435.000000  399.0
# 13                      max tps   0.009850  277.000000  394.0
# 14                      max tnr   0.997626    1.000000    0.0
# 15                      max fnr   0.997626    0.996390    0.0
# 16                      max fpr   0.002858    1.000000  399.0
# 17                      max tpr   0.009850    1.000000  394.0
# Gains/Lift Table: Avg response rate: 38,90 %, avg score: 38,81 %
#      group  cumulative_data_fraction  lower_threshold      lift
# 0        1                  0.011236         0.994822  2.570397  \
# 1        2                  0.021067         0.992279  2.203198
# 2        3                  0.030899         0.989668  2.570397
# 3        4                  0.040730         0.989034  2.203198
# 4        5                  0.050562         0.987703  2.570397
# 5        6                  0.101124         0.975900  2.498997
# 6        7                  0.150281         0.943811  2.350077
# 7        8                  0.200843         0.896595  2.356197
# 8        9                  0.303371         0.649977  1.725335
# 9       10                  0.400281         0.378020  0.931303
# 10      11                  0.500000         0.191125  0.651650
# 11      12                  0.599719         0.125877  0.470636
# 12      13                  0.699438         0.084174  0.362028
# 13      14                  0.799157         0.050448  0.398231
# 14      15                  0.898876         0.028223  0.217217
# 15      16                  1.000000         0.002858  0.392700
#
#     cumulative_lift  response_rate     score  cumulative_response_rate
# 0          2.570397       1.000000  0.995614                  1.000000  \
# 1          2.399037       0.857143  0.993793                  0.933333
# 2          2.453561       1.000000  0.990927                  0.954545
# 11          0.392282      0.934977         0.920976       2.570397
# 12          0.381764      0.935454         0.922278       2.570397
# 13          0.372860      0.936006         0.923264       2.570397
# 14          0.364756      0.937753         0.924647       2.570397
# 15          0.357475      0.939172         0.926180       2.570397
# 16          0.350779      0.941213         0.927932       2.570397
# 17          0.343267      0.941566         0.929049       2.570397
# 18          0.337638      0.942836         0.930455       2.570397
# 19          0.332060      0.944330         0.932018       2.570397
#
#     training_classification_error
# 0                        0.610955
# 1                        0.151685
# 2                        0.140449
# 3                        0.140449
# 4                        0.139045
# 5                        0.134831
# 6                        0.133427
# 7                        0.133427
# 8                        0.127809
# 9                        0.126404
# 10                       0.126404
# 11                       0.125000
# 12                       0.122191
# 13                       0.117978
# 14                       0.119382
# 15                       0.117978
# 16                       0.119382
# 17                       0.115169
# 18                       0.115169
# 19                       0.112360
# See the whole table with table.as_data_frame()
#
# Variable Importances:
#    variable  relative_importance  scaled_importance  percentage
# 0       Sex           264.055176           1.000000    0.395893
# 1       Age           112.030830           0.424271    0.167966
# 2    Pclass            89.169281           0.337692    0.133690
# 3      Fare            81.935356           0.310296    0.122844
# 4    Ticket            62.381336           0.236244    0.093527
# 5     SibSp            43.783131           0.165811    0.065643
# 6  Embarked            10.284788           0.038949    0.015420
# 7     Parch             3.346562           0.012674    0.005017

# %% [markdown]
# ## Exemplo: Prever a classe económica do passageiro
# ---

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                     Name     Sex   Age  SibSp
# 0                                Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                                 Heikkinen, Miss. Laina  female  26.0      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                               Allen, Mr. William Henry    male  35.0      0
# ..                                                   ...     ...   ...    ...
# 886                                Montvila, Rev. Juozas    male  27.0      0
# 887                         Graham, Miss. Margaret Edith  female  19.0      0
# 888             Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                                Behr, Mr. Karl Howell    male  26.0      0
# 890                                  Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
X = titanic_df.drop(['Pclass', 'PassengerId', 'Name', 'Cabin', 'Ticket'], axis=1)
X['Sex'] = (X['Sex'] == 'male').astype(int)
X = pd.concat([X.drop('Embarked', axis=1),
               pd.get_dummies(X['Embarked'], prefix='Embarked', drop_first=True).astype(int)],
              axis=1)
y = titanic_df['Pclass']
# Out:
# (712, 8) (179, 8) (712,) (179,)

# %%
X.dropna(inplace=True)
y = y.loc[X.index]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (571, 8) (143, 8) (571,) (143,)

# %%
y1_train = (y_train == 1).astype(int)
y1_train
# Out:
# 212    0
# 281    0
# 190    0
# 860    0
# 204    0
#       ..
# 124    1
# 400    0
# 479    0
# 455    0
# 645    1
# Name: Pclass, Length: 571, dtype: int32

# %%
y1_test = (y_test == 1).astype(int)
y1_test
# Out:
# 651    0
# 694    1
# 797    0
# 875    0
# 505    1
#       ..
# 313    0
# 861    0
# 698    1
# 851    0
# 323    0
# Name: Pclass, Length: 143, dtype: int32

# %%
lm1 = LogisticRegression(random_state=123)
lm1.fit(X_train, y1_train)
lm1.predict_proba(X_test)[:, 1]

# %%
X2_train = X_train.loc[y1_train[y1_train==0].index]
X2_train
# Out:
#      Survived  Sex   Age  SibSp  Parch     Fare  Embarked_Q  Embarked_S
# 212         0    1  22.0      0      0   7.2500           0           1
# 281         0    1  28.0      0      0   7.8542           0           1
# 190         1    0  32.0      0      0  13.0000           0           1
# 860         0    1  41.0      2      0  14.1083           0           1
# 204         1    1  18.0      0      0   8.0500           0           1
# ..        ...  ...   ...    ...    ...      ...         ...         ...
# 134         0    1  25.0      0      0  13.0000           0           1
# 20          0    1  35.0      0      0  26.0000           0           1
# 400         1    1  39.0      0      0   7.9250           0           1
# 479         1    0   2.0      0      1  12.2875           0           1
# 455         1    1  29.0      0      0   7.8958           0           0
#
# [415 rows x 8 columns]

# %%
y2_train = y_train.loc[X2_train.index]
y2_train = (y2_train == 2).astype(int)
y2_train
# Out:
# 212    0
# 281    0
# 190    1
# 860    0
# 204    0
#       ..
# 134    1
# 20     1
# 400    0
# 479    0
# 455    0
# Name: Pclass, Length: 415, dtype: int32

# %%
lm2 = LogisticRegression(random_state=123)
lm2.fit(X2_train, y2_train)
# Out:
# C:\Users\joaop\.conda\envs\env\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=123)

# %%
prob1 = lm1.predict_proba(X_test)[:, 1]
prob2 = (1 - lm1.predict_proba(X_test)[:, 1]) * lm2.predict_proba(X_test)[:, 1]
prob3 = (1 - lm1.predict_proba(X_test)[:, 1]) * (1 - lm2.predict_proba(X_test)[:, 1])

# %%
gbm_new = GradientBoostingClassifier(random_state=123)
gbm_new.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=123)

# %%
y_pred = gbm_new.predict(X_test)
y_pred
# Out:
# array([2, 1, 3, 3, 1, 3, 3, 2, 1, 2, 3, 3, 3, 2, 1, 2, 2, 3, 2, 3, 2, 2,
#        1, 3, 3, 2, 3, 3, 2, 3, 2, 3, 1, 3, 3, 3, 3, 3, 3, 2, 1, 3, 2, 1,
#        2, 3, 3, 2, 1, 3, 3, 3, 2, 3, 1, 3, 2, 3, 3, 3, 1, 1, 3, 3, 3, 3,
#        3, 2, 3, 3, 3, 3, 3, 3, 1, 1, 3, 3, 3, 3, 3, 3, 1, 1, 2, 1, 1, 1,
#        3, 3, 3, 3, 3, 3, 3, 2, 1, 1, 3, 3, 3, 2, 3, 2, 3, 3, 1, 3, 3, 2,
#        2, 1, 1, 1, 2, 3, 3, 2, 3, 3, 2, 3, 1, 3, 3, 2, 1, 3, 3, 3, 3, 1,
#        1, 2, 3, 3, 2, 3, 3, 2, 1, 3, 2], dtype=int64)

# %%
pd.crosstab(y_test, y_pred)
# Out:
# col_0    1   2   3
# Pclass
# 1       29   0   1
# 2        1  32   3
# 3        0   1  76

# %%
gbm_new.predict_proba(X_test)
# Out:
# array([[1.43463840e-02, 8.35026725e-01, 1.50626891e-01],
#        [9.81574611e-01, 1.72912252e-02, 1.13416400e-03],
#        [1.68629280e-03, 2.75478216e-03, 9.95558925e-01],
#        [1.29678570e-03, 4.15494108e-03, 9.94548273e-01],
#        [9.95105193e-01, 3.93225814e-03, 9.62548487e-04],
